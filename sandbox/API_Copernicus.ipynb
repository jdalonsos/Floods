# %%
# %pip install cdsapi
# Out:
# Collecting cdsapi
#   Using cached cdsapi-0.7.7-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting ecmwf-datastores-client>=0.4.0 (from cdsapi)
#   Using cached ecmwf_datastores_client-0.5.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.5.0 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from cdsapi) (2.32.5)
# Requirement already satisfied: tqdm in d:\m2_mosef\datacollection\.venv\lib\site-packages (from cdsapi) (4.67.1)
# Requirement already satisfied: attrs in d:\m2_mosef\datacollection\.venv\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (25.4.0)
# Collecting multiurl>=0.3.7 (from ecmwf-datastores-client>=0.4.0->cdsapi)
#   Using cached multiurl-0.3.7-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing-extensions in d:\m2_mosef\datacollection\.venv\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (4.15.0)
# Requirement already satisfied: pytz in d:\m2_mosef\datacollection\.venv\lib\site-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2025.2)
# Requirement already satisfied: python-dateutil in d:\m2_mosef\datacollection\.venv\lib\site-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (2025.11.12)
# Requirement already satisfied: six>=1.5 in d:\m2_mosef\datacollection\.venv\lib\site-packages (from python-dateutil->multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (1.17.0)
# Requirement already satisfied: colorama in d:\m2_mosef\datacollection\.venv\lib\site-packages (from tqdm->cdsapi) (0.4.6)
# Using cached cdsapi-0.7.7-py2.py3-none-any.whl (12 kB)
# Using cached ecmwf_datastores_client-0.5.1-py3-none-any.whl (29 kB)
# Using cached multiurl-0.3.7-py3-none-any.whl (21 kB)
# Installing collected packages: multiurl, ecmwf-datastores-client, cdsapi
#
#    ------------- -------------------------- 1/3 [ecmwf-datastores-client]
#    ---------------------------------------- 3/3 [cdsapi]
#
# Successfully installed cdsapi-0.7.7 ecmwf-datastores-client-0.5.1 multiurl-0.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import cdsapi

dataset = "derived-utci-historical"
request = {
    "variable": ["universal_thermal_climate_index"],
    "version": "1_1",
    "year": ["2026"],
    "month": ["03"],
    "day": ["30"]
}

client = cdsapi.Client()
client.retrieve(dataset, request).download()
# Out:
# d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\client.py:87: UserWarning: 404 Client Error: Not Found for url: https://cds.climate.copernicus.eu/api/v2/catalogue/v1/messages
# Exception: Climate Data Store API endpoint not found
#
# It seems you are trying to access an API endpoint that does not exist.
#
# It is possible that you are pointing to an outdated API endpoint which has been removed/renamed.
#
# Your api client version and/or configuration file may need to be updated.
#
# For users of the standard cdsapi Python library, please proceed as follows:
# - update your cdsapi client to the latest version available
# - update your .cdsapirc file as expected ("url" should be set to https://cds.climate.copernicus.eu/api and "key" should be set to your API key WITHOUT the deprecated `<UID>:` prefix)
#
# For users of the ecmwf-datastores-client Python library (recommended for advanced users), please ensure that your ecmwf-datastores-client version is updated and your .ecmwfdatastoresrc file is correctly configured.
#
# If you are trying to access a REST API endpoint directly, please refer to the documentation for more information on how to access REST API endpoints: https://cds.climate.copernicus.eu/how-to-api
#   warnings.warn(str(exc), UserWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       4 request = {
#       5     "variable": ["universal_thermal_climate_index"],
#       6     "version": "1_1",
#    (...)      9     "day": ["30"]
#      10 }
#      12 client = cdsapi.Client()
# ---> 13 client.retrieve(dataset, request).download()
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\legacy_client.py:167, in LegacyClient.retrieve(self, name, request, target)
#     165 submitted: datastores.Remote | datastores.Results
#     166 if self.wait_until_complete:
# --> 167     submitted = self.client.submit_and_wait_on_results(
#     168         collection_id=name,
#     169         request=request,
#     170     )
#     171 else:
#     172     submitted = self.client.submit(
#     173         collection_id=name,
#     174         request=request,
#     175     )
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\client.py:430, in Client.submit_and_wait_on_results(self, collection_id, request)
#     414 def submit_and_wait_on_results(
#     415     self, collection_id: str, request: dict[str, Any]
#     416 ) -> datastores.Results:
#     417     """Submit a request and wait for the results to be ready.
#     418
#     419     Parameters
#    (...)    428     datastores.Results
#     429     """
# --> 430     return self._retrieve_api.submit(collection_id, request).get_results()
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\processing.py:753, in Processing.submit(self, collection_id, request)
#     752 def submit(self, collection_id: str, request: dict[str, Any]) -> Remote:
# --> 753     return self.get_process(collection_id).submit(request)
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\processing.py:742, in Processing.get_process(self, process_id)
#     740 def get_process(self, process_id: str) -> Process:
#     741     url = f"{self.url}/processes/{process_id}"
# --> 742     return Process.from_request("get", url, **self._request_kwargs)
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\processing.py:176, in ApiResponse.from_request(cls, method, url, headers, session, retry_options, request_options, download_options, sleep_max, cleanup, log_callback, log_messages, **kwargs)
#     171 response = robust_request(
#     172     method, url, headers=headers, **request_options, **kwargs
#     173 )
#     174 log(logging.DEBUG, f"REPLY {response.text}", callback=log_callback)
# --> 176 cads_raise_for_status(response)
#     178 self = cls(
#     179     response,
#     180     headers=headers,
#    (...)    187     log_callback=log_callback,
#     188 )
#     189 if log_messages:
#
# File d:\M2_MoSEF\DataCollection\.venv\Lib\site-packages\ecmwf\datastores\processing.py:99, in cads_raise_for_status(response)
#      92     else:
#      93         message = "\n".join(
#      94             [
#      95                 f"{response.status_code} Client Error: {response.reason} for url: {response.url}",
#      96                 error_json_to_message(error_json),
#      97             ]
#      98         )
# ---> 99         raise requests.HTTPError(message, response=response)
#     100 response.raise_for_status()
#
# HTTPError: 404 Client Error: Not Found for url: https://cds.climate.copernicus.eu/api/v2/retrieve/v1/processes/derived-utci-historical
# Exception: Climate Data Store API endpoint not found
#
# It seems you are trying to access an API endpoint that does not exist.
#
# It is possible that you are pointing to an outdated API endpoint which has been removed/renamed.
#
# Your api client version and/or configuration file may need to be updated.
#
# For users of the standard cdsapi Python library, please proceed as follows:
# - update your cdsapi client to the latest version available
# - update your .cdsapirc file as expected ("url" should be set to https://cds.climate.copernicus.eu/api and "key" should be set to your API key WITHOUT the deprecated `<UID>:` prefix)
#
# For users of the ecmwf-datastores-client Python library (recommended for advanced users), please ensure that your ecmwf-datastores-client version is updated and your .ecmwfdatastoresrc file is correctly configured.
#
# If you are trying to access a REST API endpoint directly, please refer to the documentation for more information on how to access REST API endpoints: https://cds.climate.copernicus.eu/how-to-api
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install cdsapi
# Out:
# Requirement already satisfied: cdsapi in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (0.7.7)
# Requirement already satisfied: ecmwf-datastores-client>=0.4.0 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from cdsapi) (0.5.1)
# Requirement already satisfied: requests>=2.5.0 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from cdsapi) (2.32.5)
# Requirement already satisfied: tqdm in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from cdsapi) (4.67.1)
# Requirement already satisfied: attrs in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (25.4.0)
# Requirement already satisfied: multiurl>=0.3.7 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (0.3.7)
# Requirement already satisfied: typing-extensions in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (4.15.0)
# Requirement already satisfied: pytz in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2025.2)
# Requirement already satisfied: python-dateutil in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from requests>=2.5.0->cdsapi) (2025.11.12)
# Requirement already satisfied: six>=1.5 in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from python-dateutil->multiurl>=0.3.7->ecmwf-datastores-client>=0.4.0->cdsapi) (1.17.0)
# Requirement already satisfied: colorama in d:\m2_mosef\acclim\datacollection\.venv\lib\site-packages (from tqdm->cdsapi) (0.4.6)
